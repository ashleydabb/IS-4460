# %% [markdown]
# <a href="https://colab.research.google.com/github/ashleydabb/IS-4460/blob/main/tutorials/de_uta_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Get a UTA token
#
# https://developer.rideuta.com/Registration.aspx

# %%
# !pip install xmltodict
# Out:
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Installing collected packages: xmltodict
# Successfully installed xmltodict-0.13.0

# %%
from google.colab import userdata
import xmltodict

uta_secret = userdata.get('uta')

# %%
route = "703"

# %%
import requests

url = f'http://api.rideuta.com/SIRI/SIRI.svc/VehicleMonitor/ByRoute?route={route}&onwardcalls=true&usertoken={uta_secret}'
response = requests.get(url)
print(response.text)

xml_dict = xmltodict.parse(response.text)
# Out:
# <?xml version="1.0" encoding="utf-8"?><Siri version="1.3" xmlns="http://www.siri.org.uk/siri"><ResponseTimestamp>2024-03-18T12:56:36.4654545-06:00</ResponseTimestamp><VehicleMonitoringDelivery version="1.3"><ResponseTimestamp>2024-03-18T12:56:36.4654545-06:00</ResponseTimestamp><ValidUntil>2024-03-18T12:56:46.4654545-06:00</ValidUntil><VehicleActivity><RecordedAtTime>2024-03-18T12:56:36.4654545-06:00</RecordedAtTime><MonitoredVehicleJourney><LineRef>703</LineRef><DirectionRef/><FramedVehicleJourneyRef><DataFrameRef>2024-03-18T00:00:00-06:00</DataFrameRef><DatedVehicleJourneyRef>0</DatedVehicleJourneyRef></FramedVehicleJourneyRef><PublishedLineName>RED LINE</PublishedLineName><OriginRef>0</OriginRef><DestinationRef>0</DestinationRef><Monitored>True</Monitored><VehicleLocation><Longitude>-112.004535</Longitude><Latitude>40.581353</Latitude></VehicleLocation><ProgressRate>1</ProgressRate><CourseOfJourneyRef>400673</CourseOfJourneyRef><VehicleRef>1106</VehicleRef><Extensions><LastGPSFix>2024-03-18T12:56:26.48</LastGPSFix><Scheduled>False</Scheduled><Bearing>236.9</Bearing><Speed>0</Speed><DestinationName/></Extensions></MonitoredVehicleJourney><MonitoredVehicleJourney><LineRef>703</LineRef><DirectionRef>TO MEDICAL</DirectionRef><FramedVehicleJourneyRef><DataFrameRef>2024-03-18T00:00:00-06:00</DataFrameRef><DatedVehicleJourneyRef>5281607</DatedVehicleJourneyRef></FramedVehicleJourneyRef><PublishedLineName>RED LINE</PublishedLineName><OriginRef>TX101715</OriginRef><DestinationRef>TX127252</DestinationRef><Monitored>True</Monitored><VehicleLocation><Longitude>-111.890887</Longitude><Latitude>40.759727</Latitude></VehicleLocation><ProgressRate>1</ProgressRate><CourseOfJourneyRef>400951</CourseOfJourneyRef><VehicleRef>1114</VehicleRef><Extensions><LastGPSFix>2024-03-18T12:56:25.183</LastGPSFix><Scheduled>False</Scheduled><Bearing>0.1</Bearing><Speed>9.2064</Speed><DestinationName>University Medical</DestinationName></Extensions></MonitoredVehicleJourney><MonitoredVehicleJourney><LineRef>703</LineRef><DirectionRef/><FramedVehicleJourneyRef><DataFrameRef>2024-03-18T00:00:00-06:00</DataFrameRef><DatedVehicleJourneyRef>0</DatedVehicleJourneyRef></FramedVehicleJourneyRef><PublishedLineName>RED LINE</PublishedLineName><OriginRef>0</OriginRef><DestinationRef>0</DestinationRef><Monitored>True</Monitored><VehicleLocation><Longitude>-111.86384266666667</Longitude><Latitude>40.760687833333336</Latitude></VehicleLocation><ProgressRate>1</ProgressRate><CourseOfJourneyRef>400885</CourseOfJourneyRef><VehicleRef>1120</VehicleRef><Extensions><LastGPSFix>2024-03-18T12:56:23.293</LastGPSFix><Scheduled>False</Scheduled><Bearing>269.5</Bearing><Speed>17.14692</Speed><DestinationName/></Extensions></MonitoredVehicleJourney><MonitoredVehicleJourney><LineRef>703</LineRef><DirectionRef/><FramedVehicleJourneyRef><DataFrameRef>2024-03-18T00:00:00-06:00</DataFrameRef><DatedVehicleJourneyRef>0</DatedVehicleJourneyRef></FramedVehicleJourneyRef><PublishedLineName>RED LINE</PublishedLineName><OriginRef>0</OriginRef><DestinationRef>0</DestinationRef><Monitored>True</Monitored><VehicleLocation><Longitude>-112.020248</Longitude><Latitude>40.549417</Latitude></VehicleLocation><ProgressRate>1</ProgressRate><CourseOfJourneyRef>400820</CourseOfJourneyRef><VehicleRef>1128</VehicleRef><Extensions><LastGPSFix>2024-03-18T12:56:25.48</LastGPSFix><Scheduled>False</Scheduled><Bearing>322.7</Bearing><Speed>39.334344</Speed><DestinationName/></Extensions></MonitoredVehicleJourney><MonitoredVehicleJourney><LineRef>703</LineRef><DirectionRef/><FramedVehicleJourneyRef><DataFrameRef>2024-03-18T00:00:00-06:00</DataFrameRef><DatedVehicleJourneyRef>0</DatedVehicleJourneyRef></FramedVehicleJourneyRef><PublishedLineName>RED LINE</PublishedLineName><OriginRef>0</OriginRef><DestinationRef>0</DestinationRef><Monitored>True</Monitored><VehicleLocation><Longitude>-111.8984895</Longitude><Latitude>40.634210166666669</Latitude></VehicleLocation><ProgressRate>1</ProgressRate><CourseOfJourneyRef>4008 ...

# %%
xml_dict['Siri']['VehicleMonitoringDelivery']['VehicleActivity']['MonitoredVehicleJourney']
# Out:
# [{'LineRef': '703',
#   'DirectionRef': None,
#   'FramedVehicleJourneyRef': {'DataFrameRef': '2024-03-18T00:00:00-06:00',
#    'DatedVehicleJourneyRef': '0'},
#   'PublishedLineName': 'RED LINE',
#   'OriginRef': '0',
#   'DestinationRef': '0',
#   'Monitored': 'True',
#   'VehicleLocation': {'Longitude': '-112.004535', 'Latitude': '40.581353'},
#   'ProgressRate': '1',
#   'CourseOfJourneyRef': '400673',
#   'VehicleRef': '1106',
#   'Extensions': {'LastGPSFix': '2024-03-18T12:56:26.48',
#    'Scheduled': 'False',
#    'Bearing': '236.9',
#    'Speed': '0',
#    'DestinationName': None}},
#  {'LineRef': '703',
#   'DirectionRef': 'TO MEDICAL',
#   'FramedVehicleJourneyRef': {'DataFrameRef': '2024-03-18T00:00:00-06:00',
#    'DatedVehicleJourneyRef': '5281607'},
#   'PublishedLineName': 'RED LINE',
#   'OriginRef': 'TX101715',
#   'DestinationRef': 'TX127252',
#   'Monitored': 'True',
#   'VehicleLocation': {'Longitude': '-111.890887', 'Latitude': '40.759727'},
#   'ProgressRate': '1',
#   'CourseOfJourneyRef': '400951',
#   'VehicleRef': '1114',
#   'Extensions': {'LastGPSFix': '2024-03-18T12:56:25.183',
#    'Scheduled': 'False',
#    'Bearing': '0.1',
#    'Speed': '9.2064',
#    'DestinationName': 'University Medical'}},
#  {'LineRef': '703',
#   'DirectionRef': None,
#   'FramedVehicleJourneyRef': {'DataFrameRef': '2024-03-18T00:00:00-06:00',
#    'DatedVehicleJourneyRef': '0'},
#   'PublishedLineName': 'RED LINE',
#   'OriginRef': '0',
#   'DestinationRef': '0',
#   'Monitored': 'True',
#   'VehicleLocation': {'Longitude': '-111.86384266666667',
#    'Latitude': '40.760687833333336'},
#   'ProgressRate': '1',
#   'CourseOfJourneyRef': '400885',
#   'VehicleRef': '1120',
#   'Extensions': {'LastGPSFix': '2024-03-18T12:56:23.293',
#    'Scheduled': 'False',
#    'Bearing': '269.5',
#    'Speed': '17.14692',
#    'DestinationName': None}},
#  {'LineRef': '703',
#   'DirectionRef': None,
#   'FramedVehicleJourneyRef': {'DataFrameRef': '2024-03-18T00:00:00-06:00',
#    'DatedVehicleJourneyRef': '0'},
#   'PublishedLineName': 'RED LINE',
#   'OriginRef': '0',
#   'DestinationRef': '0',
#   'Monitored': 'True',
#   'VehicleLocation': {'Longitude': '-112.020248', 'Latitude': '40.549417'},
#   'ProgressRate': '1',
#   'CourseOfJourneyRef': '400820',
#   'VehicleRef': '1128',
#   'Extensions': {'LastGPSFix': '2024-03-18T12:56:25.48',
#    'Scheduled': 'False',
#    'Bearing': '322.7',
#    'Speed': '39.334344',
#    'DestinationName': None}},
#  {'LineRef': '703',
#   'DirectionRef': None,
#   'FramedVehicleJourneyRef': {'DataFrameRef': '2024-03-18T00:00:00-06:00',
#    'DatedVehicleJourneyRef': '0'},
#   'PublishedLineName': 'RED LINE',
#   'OriginRef': '0',
#   'DestinationRef': '0',
#   'Monitored': 'True',
#   'VehicleLocation': {'Longitude': '-111.8984895',
#    'Latitude': '40.634210166666669'},
#   'ProgressRate': '1',
#   'CourseOfJourneyRef': '400881',
#   'VehicleRef': '1134',
#   'Extensions': {'LastGPSFix': '2024-03-18T12:56:24.107',
#    'Scheduled': 'False',
#    'Bearing': '189.2',
#    'Speed': '13.11912',
#    'DestinationName': None}},
#  {'LineRef': '703',
#   'DirectionRef': 'TO MEDICAL',
#   'FramedVehicleJourneyRef': {'DataFrameRef': '2024-03-18T00:00:00-06:00',
#    'DatedVehicleJourneyRef': '5281618'},
#   'PublishedLineName': 'RED LINE',
#   'OriginRef': 'TX101715',
#   'DestinationRef': 'TX127252',
#   'Monitored': 'True',
#   'VehicleLocation': {'Longitude': '-111.91893966666666',
#    'Latitude': '40.616452666666667'},
#   'ProgressRate': '1',
#   'CourseOfJourneyRef': '414964',
#   'VehicleRef': '1152',
#   'Extensions': {'LastGPSFix': '2024-03-18T12:56:24.837',
#    'Scheduled': 'False',
#    'Bearing': '61.2',
#    'Speed': '48.333600000000004',
#    'DestinationName': 'University Medical'}},
#  {'LineRef': '703',
#   'DirectionRef': None,
#   'FramedVehicleJourneyRef': {'DataFrameRef': '2024-03-18T00:00:00-06:00',
#    'DatedVehicleJourneyRef': '0'},
#   'PublishedLineName': 'RED LINE',
#   'OriginRef': '0',
#   'DestinationRef': '0',
#   'Monitored': 'True',
#   'VehicleLocation': {'Longitude': '-111.8966365',
#    'Latitude': '40.687885666666666'},
#   'ProgressRate': '1',
#   'CourseOfJourneyRef': '400823',
#   'VehicleRef': '1154',
#   'Extensions': {'LastGPSFix': '2024-03-18T12:56:24.6',
#    'Scheduled': 'False',
#    'Bearing': '348.4',
#    'Speed': '7.59528',
#    'DestinationName': None}},
#  {'LineRef': '703',
#   'DirectionRef': None,
#   'FramedVehicleJourneyRef': {'DataFrameRef': '2024-03-18T00:00:00-06:00',
#    'DatedVehicleJourneyRef': '0'},
#   'PublishedLineName': 'RED LINE',
#   'OriginRef': '0',
#   'DestinationRef': '0',
#   'Monitored': 'True',
#   'VehicleLocation': {'Longitude': '-111.8969515',
#    'Latitude': '40.728444333333336'},
#   'ProgressRate': '1',
#   'CourseOfJourneyRef': '400808',
#   'VehicleRef': '1169',
#   'Extensions': {'LastGPSFix': '2024-03-18T12:56:26.403',
#    'Scheduled': 'False',
#    'Bearing': '179.1',
#    'Speed': '46.032000000000004',
#    'DestinationName': None}}]

# %%
import pandas as pd

df = pd.DataFrame(xml_dict['Siri']['VehicleMonitoringDelivery']['VehicleActivity']['MonitoredVehicleJourney'])
df
# Out:
#   LineRef DirectionRef                            FramedVehicleJourneyRef  \
# 0     703         None  {'DataFrameRef': '2024-03-18T00:00:00-06:00', ...
# 1     703   TO MEDICAL  {'DataFrameRef': '2024-03-18T00:00:00-06:00', ...
# 2     703         None  {'DataFrameRef': '2024-03-18T00:00:00-06:00', ...
# 3     703         None  {'DataFrameRef': '2024-03-18T00:00:00-06:00', ...
# 4     703         None  {'DataFrameRef': '2024-03-18T00:00:00-06:00', ...
# 5     703   TO MEDICAL  {'DataFrameRef': '2024-03-18T00:00:00-06:00', ...
# 6     703         None  {'DataFrameRef': '2024-03-18T00:00:00-06:00', ...
# 7     703         None  {'DataFrameRef': '2024-03-18T00:00:00-06:00', ...
#
#   PublishedLineName OriginRef DestinationRef Monitored  \
# 0          RED LINE         0              0      True
# 1          RED LINE  TX101715       TX127252      True
# 2          RED LINE         0              0      True
# 3          RED LINE         0              0      True
# 4          RED LINE         0              0      True
# 5          RED LINE  TX101715       TX127252      True
# 6          RED LINE         0              0      True
# 7          RED LINE         0              0      True
#
#                                      VehicleLocation ProgressRate  \
# 0  {'Longitude': '-112.004535', 'Latitude': '40.5...            1
# 1  {'Longitude': '-111.890887', 'Latitude': '40.7...            1
# 2  {'Longitude': '-111.86384266666667', 'Latitude...            1
# 3  {'Longitude': '-112.020248', 'Latitude': '40.5...            1
# 4  {'Longitude': '-111.8984895', 'Latitude': '40....            1
# 5  {'Longitude': '-111.91893966666666', 'Latitude...            1
# 6  {'Longitude': '-111.8966365', 'Latitude': '40....            1
# 7  {'Longitude': '-111.8969515', 'Latitude': '40....            1
#
#   CourseOfJourneyRef VehicleRef  \
# 0             400673       1106
# 1             400951       1114
# 2             400885       1120
# 3             400820       1128
# 4             400881       1134
# 5             414964       1152
# 6             400823       1154
# 7             400808       1169
#
#                                           Extensions
# 0  {'LastGPSFix': '2024-03-18T12:56:26.48', 'Sche...
# 1  {'LastGPSFix': '2024-03-18T12:56:25.183', 'Sch...
# 2  {'LastGPSFix': '2024-03-18T12:56:23.293', 'Sch...
# 3  {'LastGPSFix': '2024-03-18T12:56:25.48', 'Sche...
# 4  {'LastGPSFix': '2024-03-18T12:56:24.107', 'Sch...
# 5  {'LastGPSFix': '2024-03-18T12:56:24.837', 'Sch...
# 6  {'LastGPSFix': '2024-03-18T12:56:24.6', 'Sched...
# 7  {'LastGPSFix': '2024-03-18T12:56:26.403', 'Sch...

# %%
location_df = df[['VehicleLocation']]
location_df
# Out:
#                                      VehicleLocation
# 0  {'Longitude': '-112.004535', 'Latitude': '40.5...
# 1  {'Longitude': '-111.890887', 'Latitude': '40.7...
# 2  {'Longitude': '-111.86384266666667', 'Latitude...
# 3  {'Longitude': '-112.020248', 'Latitude': '40.5...
# 4  {'Longitude': '-111.8984895', 'Latitude': '40....
# 5  {'Longitude': '-111.91893966666666', 'Latitude...
# 6  {'Longitude': '-111.8966365', 'Latitude': '40....
# 7  {'Longitude': '-111.8969515', 'Latitude': '40....

# %%
# prompt: convert dict to columns in location_df

import pandas as pd
location_df = pd.json_normalize(location_df['VehicleLocation'])
location_df
# Out:
#              Longitude            Latitude
# 0          -112.004535           40.581353
# 1          -111.890887           40.759727
# 2  -111.86384266666667  40.760687833333336
# 3          -112.020248           40.549417
# 4         -111.8984895  40.634210166666669
# 5  -111.91893966666666  40.616452666666667
# 6         -111.8966365  40.687885666666666
# 7         -111.8969515  40.728444333333336

# %%
def get_locations():
    url = f'http://api.rideuta.com/SIRI/SIRI.svc/VehicleMonitor/ByRoute?route={route}&onwardcalls=true&usertoken={uta_secret}'
    response = requests.get(url)
    xml_dict = xmltodict.parse(response.text)
    df = pd.DataFrame(xml_dict['Siri']['VehicleMonitoringDelivery']['VehicleActivity']['MonitoredVehicleJourney'])
    location_df = pd.json_normalize(df['VehicleLocation'])
    return location_df

# %%
import folium

# Create a base map centered at the specified latitude and longitude.
map = folium.Map(location=[40.7128, -111.85], zoom_start=12)

location_df = get_locations()

# Add a marker to the map at the specified latitude and longitude.
for (lat, lon) in zip(location_df['Latitude'], location_df['Longitude']):
    folium.Marker([lat, lon], popup='UTA Bus Stop').add_to(map)

# Display the map.
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6804b412bc6ed1702042a3a993c6c11e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6804b412bc6ed1702042a3a993c6c11e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6804b412bc6ed1702042a3a993c6c11e = L.map(
#                 &quot;map_6804b412bc6ed1702042a3a993c6c11e&quot;,
#                 {
#                     center: [40.7128, -111.85],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_243262e9e88ab0649f733041e5e66bf9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6804b412bc6ed1702042a3a993c6c11e);
#
#
#             var marker_d99e7b7b2bb13ea1d3e9e46c3d73c13a = L.marker(
#                 [40.76065233333333, -111.86697433333333],
#                 {}
#             ).addTo(map_6804b412bc6ed1702042a3a993c6c11e);
#
#
#         var popup_e6d006d40d01c8e3a939d882c63dea89 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6d0e2e0c79b81969cfae7d23eb205bac = $(`&lt;div id=&quot;html_6d0e2e0c79b81969cfae7d23eb205bac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UTA Bus Stop&lt;/div&gt;`)[0];
#                 popup_e6d006d40d01c8e3a939d882c63dea89.setContent(html_6d0e2e0c79b81969cfae7d23eb205bac);
#
#
#
#         marker_d99e7b7b2bb13ea1d3e9e46c3d73c13a.bindPopup(popup_e6d006d40d01c8e3a939d882c63dea89)
#         ;
#
#
#
#
#             var marker_eaebb7148c3d4e7ff468ea2cd236d2f4 = L.marker(
#                 [40.760688, -111.8789445],
#                 {}
#             ).addTo(map_6804b412bc6ed1702042a3a993c6c11e);
#
#
#         var popup_31ab6032a08194b2dcf31c1543880933 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b12336e0baf7ab4567233133594111c1 = $(`&lt;div id=&quot;html_b12336e0baf7ab4567233133594111c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UTA Bus Stop&lt;/div&gt;`)[0];
#                 popup_31ab6032a08194b2dcf31c1543880933.setContent(html_b12336e0baf7ab4567233133594111c1);
#
#
#
#         marker_eaebb7148c3d4e7ff468ea2cd236d2f4.bindPopup(popup_31ab6032a08194b2dcf31c1543880933)
#         ;
#
#
#
#
#             var marker_a14449c2d7caf604c1c32a49ba005241 = L.marker(
#                 [40.582724166666665, -112.001695],
#                 {}
#             ).addTo(map_6804b412bc6ed1702042a3a993c6c11e);
#
#
#         var popup_841bb5df87e8ed4f4179fb399d612b3c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7da417c67e51f54fcd0e941259a1140a = $(`&lt;div id=&quot;html_7da417c67e51f54fcd0e941259a1140a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UTA Bus Stop&lt;/div&gt;`)[0];
#                 popup_841bb5df87e8ed4f4179fb399d612b3c.setContent(html_7da417c67e51f54fcd0e941259a1140a);
#
#
#
#         marker_a14449c2d7caf604c1c32a49ba005241.bindPopup(popup_841bb5df87e8ed4f4179fb399d612b3c)
#         ;
#
#
#
#
#             var marker_b633d7fb951612e48ace5541f6c86b19 = L.marker(
#                 [40.60796833333333, -111.92466683333333],
#                 {}
#             ).addTo(map_6804b412bc6ed1702042a3a993c6c11e);
#
#
#         var popup_23991c9640a851865f8563d598dce47c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a1f057e2baabef8f07c9410c43aaf449 = $(`&lt;div id=&quot;html_a1f057e2baabef8f07c9410c43aaf449&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UTA Bus Stop&lt;/div&gt;`)[0];
#                 popup_23991c9640a851865f8563d598dce47c.setContent(html_a1f057e2baabef8f07c9410c43aaf449);
#
#
#
#         marker_b633d7fb951612e48ace5541f6c86b19.bindPopup(popup_23991c9640a851865f8563d598dce47c)
#         ;
#
#
#
#
#             var marker_b288917e79e3f15c344971e6286558cf = L.marker(
#                 [40.633615, -111.898242],
#                 {}
#             ).addTo(map_6804b412bc6ed1702042a3a993c6c11e);
#
#
#         var popup_8aa09c447cba907ab59950807ad7fa1a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ee79bc670235255142c1f0e55eb40ad3 = $(`&lt;div id=&quot;html_ee79bc670235255142c1f0e55eb40ad3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UTA Bus Stop&lt;/div&gt;`)[0];
#                 popup_8aa09c447cba907ab59950807ad7fa1a.setContent(html_ee79bc670235255142c1f0e55eb40ad3);
#
#
#
#         marker_b288917e79e3f15c344971e6286558cf.bindPopup(popup_8aa09c447cba907ab59950807ad7fa1a)
#         ;
#
#
#
#
#             var marker_8c789ce5abbc87c9cdc9186d8fd5ea27 = L.marker(
